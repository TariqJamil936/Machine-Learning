# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# Load your data into a Pandas DataFrame
df = pd.read_csv("train.csv")

# Generate the profile report
profile = ProfileReport(df, title="My Data Profile")

# Display the report (e.g., in a Jupyter Notebook)
profile
# Or save the report to an HTML file
profile.to_file("my_data_report.html")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 653.07it/s]00:00, 41.12it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:02<00:00, 19.57it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  6.85it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.16it/s]
